# %%
from sklearn import preprocessing
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

df = pd.read_csv("../avg/all_data.csv")

# %%
df.drop(columns=["sno"], inplace=True)
df.head()
# Out:
#    Unnamed: 0  AFRDifference[AFR]  BatteryVoltage[BatteryVoltage]  \
# 0           0           49.366667                    13117.956000
# 1           1           65.718667                    13112.725333
# 2           2           75.470667                    13148.148000
# 3           3           69.436000                    13139.829333
# 4           4           70.928000                    13146.782667
#
#    EngineRunningTime[Time_s]  IgnitionTiming[Angle]  AirTemp[Temperature]  \
# 0                 169.325333             234.240000           3025.220000
# 1                 230.282667             181.676000           3050.869333
# 2                 291.270667             195.848000           3075.520000
# 3                 352.062667             209.702667           3097.037333
# 4                 412.816000             199.154667           3116.424000
#
#    CoolantTemp[Temperature]  MAPSource[Pressure]  LambdaSensor1[AFR]  \
# 0               3273.185333           435.850667          947.790667
# 1               3335.005333           523.414667          929.182667
# 2               3370.689333           439.125333          922.978667
# 3               3403.994667           372.801333          930.444000
# 4               3455.920000           364.829333          928.985333
#
#    BaseFuel[Percentage]  BaseIgnition[AngleIgnSprt2K]  \
# 0            409.857333                    314.857333
# 1            473.272000                    292.830667
# 2            404.854667                    306.161333
# 3            353.442667                    318.649333
# 4            355.814667                    318.990667
#
#    IgnitionCoolantTempCorrection[AngleOffset10deg]  \
# 0                                       168.356000
# 1                                       142.698667
# 2                                       144.117333
# 3                                       145.018667
# 4                                       135.025333
#
#    IgnitionAirTempCorrection[Angle]  RPM[EngineSpeed]
# 0                         49.534667       1480.309333
# 1                         46.049333       1794.726667
# 2                         45.597333       1531.942667
# 3                         46.034667       1220.672000
# 4                         45.145333       1239.245333

# %% [markdown]
# Features Used:

# %%
features = [
    'IgnitionTiming[Angle]', 
    'MAPSource[Pressure]', 
    'RPM[EngineSpeed]', 
    'AFRDifference[AFR]', 
    'BatteryVoltage[BatteryVoltage]', 
    'AirTemp[Temperature]', 
    'CoolantTemp[Temperature]', 
    'LambdaSensor1[AFR]', 
    'BaseFuel[Percentage]', 
    'BaseIgnition[AngleIgnSprt2K]'
]

df_feature = df[features]
df_feature.head()
# Out:
#    IgnitionTiming[Angle]  MAPSource[Pressure]  RPM[EngineSpeed]  \
# 0             234.240000           435.850667       1480.309333
# 1             181.676000           523.414667       1794.726667
# 2             195.848000           439.125333       1531.942667
# 3             209.702667           372.801333       1220.672000
# 4             199.154667           364.829333       1239.245333
#
#    AFRDifference[AFR]  BatteryVoltage[BatteryVoltage]  AirTemp[Temperature]  \
# 0           49.366667                    13117.956000           3025.220000
# 1           65.718667                    13112.725333           3050.869333
# 2           75.470667                    13148.148000           3075.520000
# 3           69.436000                    13139.829333           3097.037333
# 4           70.928000                    13146.782667           3116.424000
#
#    CoolantTemp[Temperature]  LambdaSensor1[AFR]  BaseFuel[Percentage]  \
# 0               3273.185333          947.790667            409.857333
# 1               3335.005333          929.182667            473.272000
# 2               3370.689333          922.978667            404.854667
# 3               3403.994667          930.444000            353.442667
# 4               3455.920000          928.985333            355.814667
#
#    BaseIgnition[AngleIgnSprt2K]
# 0                    314.857333
# 1                    292.830667
# 2                    306.161333
# 3                    318.649333
# 4                    318.990667

# %% [markdown]
# Model :

# %%
epsilon = 0.5
minSample = 500
scaler = preprocessing.MinMaxScaler().fit(df_feature)
df_scaled = scaler.transform(df_feature)
dbscan = DBSCAN(eps=epsilon, min_samples=minSample).fit(df_scaled)
