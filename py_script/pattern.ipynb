# %%
import numpy as np
import pandas as pd
import seaborn as sns
import glob
import matplotlib.pyplot as plt


df = pd.read_csv("../avg/all_data.csv")
df.head()
# Out:
#    Unnamed: 0  AFRDifference[AFR]  BatteryVoltage[BatteryVoltage]  \
# 0           0           49.366667                    13117.956000
# 1           1           65.718667                    13112.725333
# 2           2           75.470667                    13148.148000
# 3           3           69.436000                    13139.829333
# 4           4           70.928000                    13146.782667
#
#    EngineRunningTime[Time_s]  IgnitionTiming[Angle]  AirTemp[Temperature]  \
# 0                 169.325333             234.240000           3025.220000
# 1                 230.282667             181.676000           3050.869333
# 2                 291.270667             195.848000           3075.520000
# 3                 352.062667             209.702667           3097.037333
# 4                 412.816000             199.154667           3116.424000
#
#    CoolantTemp[Temperature]  MAPSource[Pressure]  LambdaSensor1[AFR]  \
# ...

# %%
plt.scatter(df["IgnitionTiming[Angle]"], df["MAPSource[Pressure]"])
plt.xlabel = ("Ignition Advance")
plt.ylabel = ("ManiFold Pressure")
plt.show()

# %%
plt.scatter(df["AFRDifference[AFR]"], df["MAPSource[Pressure]"])

# %%
plt.scatter(df["RPM[EngineSpeed]"], df["BatteryVoltage[BatteryVoltage]"])

# %%
plt.scatter(df["RPM[EngineSpeed]"], df["MAPSource[Pressure]"])

# %%
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(df["IgnitionTiming[Angle]"], df["MAPSource[Pressure]"], df["RPM[EngineSpeed]"], color = "green")
plt.title("simple 3D scatter plot")
plt.show()

# %%
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(df["IgnitionTiming[Angle]"], df["RPM[EngineSpeed]"], df["MAPSource[Pressure]"], color = "green")
plt.title("simple 3D scatter plot")
plt.show()

# %%
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(df["AirTemp[Temperature]"], df["RPM[EngineSpeed]"], df["IgnitionAirTempCorrection[Angle]"], color = "green")
plt.title("simple 3D scatter plot")
plt.show()
